# %%
from datetime import timedelta, datetime
import glob
from itertools import chain
import json
import os
import re
import math
import numpy as np
import pandas as pd

# %%
from gensim.models import Word2Vec
from gensim.models.keyedvectors import WordEmbeddingsKeyedVectors

# %%
song_meta = pd.read_json('../res/song_meta.json', typ = 'frame')

# %%
song_meta.head()
# Out:
#   song_gn_dtl_gnr_basket  issue_date  \
# 0               [GN0901]    20140512
# 1       [GN1601, GN1606]    20080421
# 2               [GN0901]    20180518
# 3       [GN1102, GN1101]    20151016
# 4       [GN1802, GN1801]    20110824
#
#                                           album_name  album_id  \
# 0                       불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
# 1                      Bach : Partitas Nos. 2, 3 & 4    376431
# 2                                                Hit   4698747
# 3  Feeling Right (Everything Is Nice) (Feat. Popc...   2644882
# 4                                            그남자 그여자   2008470
#
#   artist_id_basket                                          song_name  \
# 0           [2727]                                           Feelings
# 1          [29966]  Bach : Partita No. 4 In D Major, BWV 828 - II....
# 2           [3361]                    Solsbury Hill (Remastered 2002)
# 3         [838543]  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4         [560160]                                            그남자 그여자
#
#   song_gn_gnr_basket artist_name_basket  id
# 0           [GN0900]  [Various Artists]   0
# 1           [GN1600]   [Murray Perahia]   1
# 2           [GN0900]    [Peter Gabriel]   2
# 3           [GN1100]           [Matoma]   3
# 4           [GN1800]         [Jude Law]   4

# %%
song_meta_indexed = song_meta.set_index('id')

# %%
song_artist = []

def get_song_artist(song, artist_list):
    for artist in artist_list:
        if artist is not 'Various Artists':
            song_artist.append([song, artist])

# %%
result = song_meta.apply(lambda x : get_song_artist(x.id, x.artist_name_basket), axis=1)

# %%
song_artist_df = pd.DataFrame(song_artist, columns=['song', 'artist'])

# %%
song_artist_df = song_artist_df.set_index('song')

# %%
song_album_df = song_meta[['id', 'album_id']]

# %%
song_album_df.columns = ['song', 'album']

# %%
song_album_df =  song_album_df.set_index('song')

# %%
song_gn = []

def get_song_gn(song, gn_list):
    if len(gn_list) == 0:
        song_gn.append([song, 'nogn'])
    else:
        for gn in gn_list:
            song_gn.append([song, gn])

# %%
result = song_meta.apply(lambda x : get_song_gn(x.id, x.song_gn_dtl_gnr_basket), axis=1)

# %%
song_gn_df = pd.DataFrame(song_gn, columns=['song', 'gn'])

# %%
song_gn_df = song_gn_df.set_index('song')

# %%
train = pd.read_json('../res/train.json', typ = 'frame')

# %%
val = pd.read_json('../res/val.json', typ = 'frame')

# %%
test = pd.read_json('../res/test.json', typ = 'frame')

# %%
train['songs_len'] = train['songs'].apply(lambda x : len(x))
train['tags_len'] = train['tags'].apply(lambda x : len(x))
val['songs_len'] = val['songs'].apply(lambda x : len(x))
val['tags_len'] = val['tags'].apply(lambda x : len(x))
test['songs_len'] = test['songs'].apply(lambda x : len(x))
test['tags_len'] = test['tags'].apply(lambda x : len(x))

# %%
model = Word2Vec.load("song2vec.model")

# %%
song_song_list = []

# %%
song_song_count = 0

# %%
def co_occur_song(song_list):
    global song_song_count
    if song_song_count % 10000 == 0:
        print(f'===== working at {song_song_count},  {datetime.now()} =====')
    for idx1,song1 in enumerate(song_list):
        for idx2,song2 in enumerate(song_list[idx1:idx1+30]):
            if song1 is not song2:
                song_song_list.append([song1, song2])
                song_song_list.append([song2, song1])
    song_song_count = song_song_count + 1

# %%
result = train['songs'].apply(co_occur_song)
# Out:
# ===== working at 0,  2020-07-20 17:12:39.607566 =====
# ===== working at 10000,  2020-07-20 17:12:42.634616 =====
# ===== working at 20000,  2020-07-20 17:12:45.509840 =====
# ===== working at 30000,  2020-07-20 17:12:48.538867 =====
# ===== working at 40000,  2020-07-20 17:12:51.544460 =====
# ===== working at 50000,  2020-07-20 17:13:02.598847 =====
# ===== working at 60000,  2020-07-20 17:13:14.965690 =====
# ===== working at 70000,  2020-07-20 17:13:17.895426 =====
# ===== working at 80000,  2020-07-20 17:13:32.022052 =====
# ===== working at 90000,  2020-07-20 17:13:35.014643 =====
# ===== working at 100000,  2020-07-20 17:13:51.199553 =====
# ===== working at 110000,  2020-07-20 17:13:54.119299 =====

# %%
co_song_df = pd.DataFrame(song_song_list, columns=['sa', 'sb'])

# %%
co_song_df.shape
# Out:
# (215131424, 2)

# %%
co_song_count_df = co_song_df.groupby(['sa', 'sb']).size().reset_index().set_index('sa')

# %%
co_song_count_df.shape
# Out:
# (138395578, 2)

# %%
co_song_count_df.columns = ['sb', 'count']

# %%
co_song_count_df['count_scale'] = co_song_count_df['count'].apply(lambda x : math.log(x+1))

# %%
pp_song_count_df = co_song_df.groupby('sa').size().sort_values(ascending=False).reset_index().set_index('sa')

# %%
tag_song_list = []

# %%
def co_occur_tag_song(song_list, tag_list):
    tags = list(set(tag_list))
    for tag in tags:
        for song in song_list:
            tag_song_list.append([tag, song])

# %%
result = train.apply(lambda x : co_occur_tag_song(x.songs, x.tags), axis=1)

# %%
co_tag_song_df = pd.DataFrame(tag_song_list, columns=['tag', 'song'])

# %%
co_tag_song_df_indexed =  co_tag_song_df.set_index('tag')

# %%
co_tag_song_count_df = co_tag_song_df.groupby(['tag', 'song']).size().reset_index()

# %%
co_tag_song_count_df.columns = ['tag', 'song', 'count']

# %%
co_tag_song_count_df['count_scale'] = co_tag_song_count_df['count'].apply(lambda x : math.log(x+1))

# %%
co_tag_song_count_df_indexed = co_tag_song_count_df.set_index('song')

# %%
pp_tag_count_df = co_tag_song_df.groupby('tag').size().sort_values(ascending=False).reset_index().set_index('tag')

# %%
song_has_tag_set = set(co_tag_song_count_df_indexed.index.tolist())

# %%
tag_tag_list = []

# %%
def co_occur_tag(tag_list):
    for tag1 in tag_list:
        for tag2 in tag_list:
            if tag1 is not tag2:
                tag_tag_list.append([tag1, tag2])

# %%
result = train['tags'].apply(co_occur_tag)

# %%
co_tag_df = pd.DataFrame(tag_tag_list, columns=['ta', 'tb'])

# %%
co_tag_count_df = co_tag_df.groupby(['ta', 'tb']).size().reset_index().set_index('ta')

# %%
co_tag_count_df.columns = ['tb', 'count']

# %%
co_tag_count_df['count_scale'] = co_tag_count_df['count'].apply(lambda x : math.log(x+1))

# %%
pp_tag_count_df = co_tag_df.groupby('ta').size().sort_values(ascending=False).reset_index().set_index('ta')

# %%
tag_has_tag_set = set(co_tag_count_df.index.tolist())

# %%
def get_reco_tag_co_occur(tag_list, size=10):
    if len(tag_list) == 0:
        return []
    
    tag_set = tag_has_tag_set & set(tag_list)
    co_tag = co_tag_count_df.loc[tag_set]
    co_tag_count = co_tag.groupby('tb')['count_scale'].sum().sort_values(ascending=False).reset_index()
    #print(co_tag_count)
    return co_tag_count[~co_tag_count['tb'].isin(tag_list)].head(size)

# %%
def reco_tag_co_occur(tag_list, size=10):
    if len(tag_list) == 0:
        return []
    reco_top = get_reco_tag_co_occur(tag_list)
    if len(reco_top) == 0:
        return []
    return reco_top['tb'].tolist()

# %%
val.iloc[21242]['tags']
# Out:
# ['힙합', '우기', '비트', 'aomg']

# %%
reco_tag_co_occur(val.iloc[14149]['tags'])
# Out:
# ['크리스마스', '캐롤', '겨울', '연말', 'Christmas', '크리스마스캐롤', '눈', '기분전환', '팝', 'Carol']

# %%
def get_reco_tag_song_co_occur(song_list, ignore_list=[], size=10):
    if len(song_list) == 0:
        return []
    
    song_set = song_has_tag_set & set(song_list)
    co_tag = co_tag_song_count_df_indexed.loc[song_set]
    co_tag_count = co_tag.groupby('tag')['count_scale'].sum().sort_values(ascending=False).reset_index()
    #print(co_tag_count.shape)
    #print(co_tag_count)
    return co_tag_count[~co_tag_count['tag'].isin(ignore_list)].head(size)

# %%
def reco_tag_song_co_occur(song_list, ignore_list=[], size=10):
    if len(song_list) == 0:
        return []
    reco_top = get_reco_tag_song_co_occur(song_list, ignore_list)
    if len(reco_top) == 0:
        return []
    return reco_top['tag'].tolist()

# %%
reco_tag_song_co_occur(val.iloc[14149]['songs'], val.iloc[14149]['tags'])
# Out:
# ['크리스마스', '겨울', '캐롤', '기분전환', '연말', '눈', '사랑', '감성', 'Christmas', '카페']

# %%
def reco_tag_song_mix(tag_list, song_list, size=10):
    reco_tag = get_reco_tag_co_occur(tag_list, 20)
    if len(reco_tag) == 0:
        return []
    reco_tag.columns = ['tag', 'count_tag']
    
    reco_song = get_reco_tag_song_co_occur(song_list, tag_list, 20)
    
    if len(reco_song) == 0:
        return reco_tag['tag'].tolist()
    
    reco_song.columns = ['tag', 'count_song']     
    reco = pd.merge(reco_tag, reco_song, how='outer', on='tag')
    reco = reco.fillna(0)
    reco['count'] = reco.apply(lambda x : x.count_tag + x.count_song * 0.1 , axis=1)
    reco = reco.sort_values('count', ascending=False)  
    #print(reco)
    return reco.head(size)['tag'].tolist()

# %%
reco_tag_song_mix(val.iloc[14149]['tags'], val.iloc[14149]['songs'])
# Out:
# ['크리스마스', '캐롤', '겨울', '연말', 'Christmas', '기분전환', '눈', '팝', '12월', '카페']

# %%
pp_tag_count_top = pp_tag_count_df.head(100)

# %%
reco_tag_count = 0
def tag_reco_final(song_list, tag_list):
    
    global reco_tag_count
    if reco_tag_count % 1000 == 0:
        print(f'===== working at {reco_tag_count},  {datetime.now()} =====')

    reco = reco_tag_co_occur(tag_list)
    #print(f'r1 : {len(reco)}')
    extra = 10 - len(reco)
    if extra > 0:
        reco.extend(reco_tag_song_co_occur(song_list, reco+tag_list, extra))
        #print(f'r2 : {len(reco)}')
    extra = 10 - len(reco)
    if extra > 0:
        reco.extend(pp_tag_count_df[~pp_tag_count_df.index.isin(reco+tag_list)].head(extra).index.tolist())
        #print(f'r3 : {len(reco)}')
    reco_tag_count = reco_tag_count + 1
    return reco[:10]

# %%
reco_tag_count = 0
def tag_reco_final(song_list, tag_list):
    global reco_tag_count
    if reco_tag_count % 1000 == 0:
        print(f'===== working at {reco_tag_count},  {datetime.now()} =====')
        
    song_len = len(song_list)
    tag_len = len(tag_list)
    reco = []
    if song_len > 0 and tag_len > 0:
        reco = reco_tag_song_mix(tag_list, song_list)
    elif song_len > 0 and tag_len == 0:
        reco = reco_tag_song_co_occur(song_list)
    elif song_len == 0 and tag_len > 0:
        reco = reco_tag_co_occur(tag_list)
    
    extra = 10 - len(reco)
    if extra > 0:
        reco.extend(pp_tag_count_top[~pp_tag_count_top.index.isin(reco+tag_list)].head(extra).index.tolist())
    reco_tag_count = reco_tag_count + 1
    return reco[:10]

# %%
val['tag_reco'] = val.apply(lambda x : tag_reco_final(x.songs, x.tags), axis=1)
# Out:
# ===== working at 0,  2020-07-21 23:53:45.896766 =====
# ===== working at 1000,  2020-07-22 00:05:26.101357 =====
# ===== working at 2000,  2020-07-22 00:17:11.292394 =====
# ===== working at 3000,  2020-07-22 00:28:50.793823 =====
# ===== working at 4000,  2020-07-22 00:40:34.448914 =====
# ===== working at 5000,  2020-07-22 00:52:37.237313 =====
# ===== working at 6000,  2020-07-22 01:04:23.505575 =====
# ===== working at 7000,  2020-07-22 01:16:33.707935 =====
# ===== working at 8000,  2020-07-22 01:28:32.525067 =====
# ===== working at 9000,  2020-07-22 01:40:28.425551 =====
# ===== working at 10000,  2020-07-22 01:52:11.480041 =====
# ===== working at 11000,  2020-07-22 02:04:24.191715 =====
# ===== working at 12000,  2020-07-22 02:16:19.955882 =====
# ===== working at 13000,  2020-07-22 02:28:16.857848 =====
# ===== working at 14000,  2020-07-22 02:40:18.883123 =====
# ===== working at 15000,  2020-07-22 02:52:28.981483 =====
# ===== working at 16000,  2020-07-22 03:04:23.954649 =====
# ===== working at 17000,  2020-07-22 03:16:14.912338 =====
# ===== working at 18000,  2020-07-22 03:27:58.331277 =====
# ===== working at 19000,  2020-07-22 03:39:57.212558 =====
# ===== working at 20000,  2020-07-22 03:51:47.608077 =====
# ===== working at 21000,  2020-07-22 04:03:33.055291 =====
# ===== working at 22000,  2020-07-22 04:15:20.597892 =====
# ===== working at 23000,  2020-07-22 04:27:08.155630 =====

# %%
val[['id', 'tag_reco']].to_csv('tag_reco_result.csv', encoding='utf-8-sig')

# %%
val[(val['songs_len'] != 0) & (val['tags_len'] != 0)].sample(30)
# Out:
#                             tags      id plylst_title  \
# 20056                     [주말휴식]   11046
# 3934   [어쿠스틱, 발라드, 띵곡, 스트레스, 인디]   15482
# 16715             [감각적인, 트렌디, 팝]    5376
# 21108            [고독, 채울수없는, 홀로]   27297
# 4211             [유니크, 제목, 색깔있는]  106685
# 5206                    [휴식, 새벽]   76901
# 20303  [내한, 감성, 싱어송라이터, 음색, 중독성]  113930
# 10030                       [힙합]   89341
# 4880                  [감성, 드라이브]   98294
# 11858           [감성, 새벽, 우울, 몽환]   94997
# 17861                   [사랑, 회상]   24430
# 12749                   [힐링, 사랑]  142337
# 19009                        [팝]  113046
# 19752               [카페, 새벽, 커피]  145019
# 8443                        [클럽]  116535
# 14231                       [담담]   42069
# 5442                      [드라이브]   86619
# 11098    [저녁, 회상, 감미로움, 설렘, 퇴근길]   45726
# 6248                        [힙합]   99353
# 10010  [힙합, 최신힙합, 스포츠, 다이어트, 국힙]   85407
# 20563                       [슬픔]  103097
# 8127        [감성, 카페, 여행, 커피, 더위]   79815
# 148                         [매장]  106524
# 442                     [슬픔, 이별]     449
# 13475                   [힐링, 휴식]   19071
# 8535      [분위기, 느낌있는, 봄비, 감성, 비]   96470
# 9985                        [까페]   56085
# 7130                  [빌로우, EDM]  138419
# 21616                    [감성발라드]   38387
# 21612                       [휴식]  110203
#
#                                                    songs  like_cnt  \
# 20056  [126538, 85170, 40478, 567046, 608049, 393222,...        11
# 3934   [570836, 209135, 389920, 582252, 547967, 48791...         1
# 16715  [507028, 473741, 339481, 537017, 351900, 19285...       393
# 21108  [517016, 300944, 92779, 617391, 473514, 253755...         4
# 4211   [364028, 165024, 406684, 357425, 204632, 34709...         1
# 5206     [152855, 670462, 180677, 397773, 12392, 301990]        10
# 20303  [466563, 261407, 371077, 135506, 681996, 29835...        24
# 10030  [419668, 80009, 255014, 597433, 518916, 425245...        20
# 4880   [9489, 174821, 14410, 531381, 547047, 27886, 3...         2
# 11858  [4816, 83504, 614472, 454522, 304937, 688985, ...        69
# 17861  [397035, 303683, 670635, 482226, 36918, 226176...         6
# 12749  [351005, 248734, 545392, 39805, 530329, 381083...       598
# 19009  [145523, 600300, 323625, 684498, 554106, 24929...     13675
# 19752  [422077, 669753, 448116, 341513, 485155, 14013...         4
# 8443   [374959, 441580, 635534, 47450, 177569, 498432...       470
# 14231  [185174, 532347, 33314, 681799, 703435, 210349...       132
# 5442   [252719, 473568, 516624, 620830, 644075, 21883...       620
# 11098  [209135, 389920, 199262, 509998, 442014, 48791...         2
# 6248   [488423, 148170, 397035, 12271, 3674, 307813, ...       353
# 10010  [638149, 689319, 350303, 409609, 65266, 188388...         5
# 20563            [666577, 111289, 585652, 48152, 564572]         0
# 8127   [637476, 507060, 24016, 462092, 92547, 431430,...         6
# 148    [464004, 582420, 260737, 248915, 507921, 43503...       380
# 442    [14864, 97094, 51612, 445950, 617391, 404995, ...        11
# 13475  [229183, 173798, 243850, 614756, 248566, 22314...        10
# 8535   [288186, 157965, 79658, 527493, 608260, 484831...         1
# 9985   [473171, 339321, 435261, 232301, 194909, 46382...       582
# 7130   [419730, 157861, 40715, 581799, 230862, 616725...        33
# 21616  [266727, 84902, 701557, 186802, 298463, 565626...        16
# 21612  [20214, 387783, 317206, 158590, 637510, 138831...         0
#
#                      updt_date  songs_len  tags_len  \
# 20056  2016-02-20 15:02:17.000         17         1
# 3934   2020-02-27 08:10:58.000         36         5
# 16715  2018-12-02 12:22:41.000         10         3
# 21108  2017-02-05 17:26:52.000         11         3
# 4211   2020-04-06 20:30:10.000         17         3
# 5206   2016-07-12 22:42:45.000          6         2
# 20303  2020-01-07 13:42:16.000          9         5
# 10030  2020-04-14 21:06:25.000          7         1
# 4880   2019-11-04 15:58:21.000         11         2
# 11858  2017-01-02 01:15:00.000          8         4
# 17861  2016-01-28 14:28:21.000         34         2
# 12749  2017-02-10 13:53:51.000         38         2
# 19009  2018-06-03 23:20:02.000         53         1
# 19752  2018-01-23 11:10:53.000         15         3
# 8443   2017-08-21 15:25:46.000        100         1
# 14231  2017-05-02 21:32:13.000          8         1
# 5442   2016-09-08 11:27:05.000         13         1
# 11098  2020-01-15 05:32:20.000         37         5
# 6248   2014-12-29 12:32:20.000         82         1
# 10010  2020-02-14 16:59:14.000         12         5
# 20563  2017-09-18 10:30:14.000          5         1
# 8127   2019-10-13 21:29:38.000         13         5
# 148    2020-03-23 14:47:57.000         50         1
# 442    2016-02-26 03:05:34.000         24         2
# 13475  2016-03-27 22:35:53.000         23         2
# 8535   2020-04-17 09:24:50.000         15         5
# 9985   2015-06-22 12:32:36.000         25         1
# 7130   2016-08-26 12:11:04.000          7         2
# 21616  2017-09-27 17:49:19.000        100         1
# 21612  2014-12-02 18:00:20.000         41         1
#
#                                                song_reco  song_reco_len  \
# 20056  [242200, 503534, 129813, 592549, 117003, 69052...            100
# 3934   [427724, 68348, 498752, 341513, 509998, 105140...            100
# 16715  [460823, 641136, 492502, 678161, 430508, 23346...            100
# 21108  [675115, 153271, 664036, 654757, 438424, 41999...            100
# 4211   [449244, 125298, 581789, 135925, 144663, 53182...            100
# 5206   [430106, 296241, 639289, 697167, 565440, 55899...            100
# 20303  [348524, 465612, 443561, 516466, 565987, 13051...            100
# 10030  [312592, 462122, 435729, 264902, 442751, 53864...            100
# 4880   [389382, 115933, 462080, 700050, 524340, 52061...            100
# 11858  [634450, 397008, 275780, 644538, 324330, 57101...            100
# 17861  [695494, 473514, 413837, 672550, 238794, 67183...            100
# 12749  [565629, 536464, 468494, 280187, 639550, 34696...            100
# 19009  [559731, 484234, 705515, 243392, 585388, 12397...            100
# 19752  [199262, 105140, 42155, 582252, 547967, 509998...            100
# 8443   [649359, 587167, 316012, 445418, 94249, 40907,...            100
# 14231  [144663, 8719, 343974, 245317, 549178, 77951, ...            100
# 5442   [508043, 592049, 463577, 551411, 420540, 12697...            100
# 11098  [157055, 105140, 582252, 38261, 680366, 235773...            100
# 6248   [528278, 116847, 661213, 237407, 176292, 41342...            100
# 10010  [633828, 329977, 683227, 288118, 249298, 18881...            100
# 20563  [446771, 27469, 357367, 185174, 676428, 289625...            100
# 8127   [49921, 664191, 366786, 233641, 576478, 71947,...            100
# 148    [231334, 495979, 649722, 28563, 165793, 520179...            100
# 442    [593128, 419993, 95928, 147228, 254695, 314910...            100
# 13475  [132994, 553437, 133143, 549178, 122363, 58178...            100
# 8535   [302864, 187246, 663905, 215411, 224731, 24309...            100
# 9985   [366786, 133143, 531765, 447666, 13281, 449244...            100
# 7130   [217365, 43627, 231320, 497546, 501764, 191915...            100
# 21616  [581789, 427256, 354659, 52904, 485957, 549547...            100
# 21612  [407828, 521739, 418935, 326204, 549178, 13142...            100
#
#                                                 tag_reco
# 20056       [기분전환, 감성, 드라이브, 휴식, 잔잔한, 카페, 힐링, 사랑, 새벽, 밤]
# 3934      [감성, 기분전환, 드라이브, 잔잔한, 카페, 휴식, 사랑, 분위기, 새벽, 산책]
# 16715  [기분전환, 드라이브, 감성, Pop, 신나는, 매장음악, 카페, 알앤비, 힙합, ...
# 21108        [발라드, 감성, 새벽, 밤, 이별, 잔잔한, 슬픔, 기분전환, 인디, 겨울]
# 4211       [감성, 기분전환, 카페, 인디, 새벽, 드라이브, 휴식, 트렌디, 신나는, 밤]
# 5206        [힐링, 잔잔한, 밤, 감성, 기분전환, 카페, 드라이브, 사랑, 추억, 가을]
# 20303    [기분전환, 팝, 신나는, 드라이브, 잔잔한, 휴식, 분위기, Pop, 카페, 힐링]
# 10030  [랩, 기분전환, 드라이브, 신나는, 클럽, HipHop, 외힙, 알앤비, 스트레스...
# 4880        [기분전환, 휴식, 카페, 잔잔한, 새벽, 밤, 매장음악, 신나는, 팝, 힐링]
# 11858    [밤, 잔잔한, 기분전환, 휴식, 드라이브, 분위기, 힐링, 비오는날, 이별, 카페]
# 17861        [추억, 기분전환, 이별, 새벽, 설렘, 밤, 휴식, 발라드, 감성, 잔잔한]
# 12749      [기분전환, 설렘, 휴식, 잔잔한, 드라이브, 감성, 새벽, 발라드, 봄, 추억]
# 19009     [기분전환, 휴식, 잔잔한, 힐링, 감성, 드라이브, 새벽, 밤, 카페, 매장음악]
# 19752      [감성, 잔잔한, 휴식, 기분전환, 발라드, 밤, 사랑, 힐링, 이별, 매장음악]
# 8443   [EDM, 일렉, 기분전환, 드라이브, 스트레스, 운동, 신나는, 일렉트로니카, 매...
# 14231        [새벽, 힐링, 밤, 기분전환, 감성, 사랑, 휴식, 이별, 잔잔한, 발라드]
# 5442      [기분전환, 힙합, 신나는, 스트레스, 운동, 팝, 여행, 매장음악, 감성, 카페]
# 11098        [사랑, 추억, 기분전환, 감성, 휴식, 카페, 밤, 잔잔한, 새벽, 발라드]
# 6248     [랩, 기분전환, 드라이브, 감성, 스트레스, 알앤비, 신나는, 운동, 휴식, 여행]
# 10010   [신나는, 운동, 기분전환, 랩, 드라이브, 헬스, 감성, 스트레스, 국내힙합, 클럽]
# 20563          [이별, 새벽, 밤, 사랑, 감성, 추억, 잔잔한, 회상, 발라드, 설렘]
# 8127     [기분전환, 휴식, 드라이브, 잔잔한, 힐링, 사랑, 여름, 발라드, 밤, 매장음악]
# 148      [카페, 재즈, 기분전환, 휴식, 드라이브, 힐링, 매장음악, 감성, 커피, 잔잔한]
# 442          [발라드, 추억, 회상, 새벽, 사랑, 밤, 감성, 잔잔한, 기분전환, 휴식]
# 13475       [기분전환, 사랑, 잔잔한, 감성, 설렘, 봄, 카페, 드라이브, 여행, 새벽]
# 8535     [잔잔한, 발라드, 카페, 기분전환, 휴식, 드라이브, 밤, 새벽, 사랑, 비오는날]
# 9985          [사랑, 휴식, 힐링, 기분전환, 잔잔한, 설렘, 새벽, 감성, 밤, 가을]
# 7130   [일렉트로니카, 신나는, electronica, 댄스, EDMFloor, dance...
# 21616      [기분전환, 드라이브, 감성, 사랑, 카페, 발라드, 잔잔한, 새벽, 밤, 이별]
# 21612     [힐링, 기분전환, 잔잔한, 사랑, 감성, 추억, 드라이브, 발라드, 새벽, 설렘]

# %%
def get_reco_song_co_occur(song_list, ignore_list=[], size=100):
    reco_list = []
    for song in song_list:
        if song in co_song_count_df.index:
            reco_s = co_song_count_df.loc[song]['sb'].tolist()
            reco_c = co_song_count_df.loc[song]['count_scale'].tolist()
            if type(reco_s) is not list:
                reco_list.append([reco_s, reco_c])
            else:
                for idx, reco in enumerate(reco_s):
                    reco_list.append([reco_s[idx], reco_c[idx]])
    reco_df = pd.DataFrame(reco_list, columns=['song', 'count_scale'])
    #print(reco_df.head(20))
    reco_count_df = reco_df.groupby(['song'])['count_scale'].sum().sort_values(ascending=False).reset_index()
    #print(reco_count_df.head(20))
    reco_top = reco_count_df[~reco_count_df['song'].isin(song_list+ignore_list)].head(size)
    #print(reco_top.head(20))

    return reco_top

# %%
def reco_song_co_occur(song_list, size=100):
    if len(song_list) == 0:
        return []
    reco_top = get_reco_song_co_occur(song_list)
    if len(reco_top) == 0:
        return []
    return reco_top['song'].tolist()

# %%
song_index = 21242

# %%
reco_result = reco_song_co_occur(val.iloc[song_index]['songs'])

# %%
len(set(reco_result))
# Out:
# 100

# %%
len(set(reco_result) & set(val.iloc[song_index]['songs']))
# Out:
# 0

# %%
song_meta_indexed.loc[val.iloc[song_index]['songs']]
# Out:
#                           song_gn_dtl_gnr_basket  issue_date  \
# id
# 686323  [GN0509, GN0501, GN0304, GN0505, GN0301]    20151105
# 425790          [GN0501, GN0304, GN0505, GN0301]    20151210
# 505516                          [GN0303, GN0301]    20160720
# 598924                          [GN0303, GN0301]    20160720
# 73959                   [GN0401, GN0403, GN0402]    20161020
# 19670                           [GN0303, GN0301]    20170425
# 588686                          [GN0303, GN0301]    20170525
# 140795                          [GN0303, GN0301]    20170525
# 644650                          [GN0303, GN0301]    20170525
# 447716                          [GN0303, GN0301]    20170525
# 927                                     [GN0301]    20170605
# 357102                          [GN0303, GN0301]    20170605
# 24303                           [GN1301, GN1302]    20171013
# 160629                  [GN0401, GN0403, GN0402]    20171015
# 460646          [GN1501, GN1504, GN0303, GN0301]    20171220
# 556615                          [GN0401, GN0403]    20180318
# 414424                          [GN0401, GN0403]    20180323
# 46084                                   [GN0101]    20180421
# 5542                            [GN0302, GN0301]    20180525
# 176997                          [GN0401, GN0403]    20180606
# 338227                  [GN0401, GN0403, GN0402]    20161020
# 130196                          [GN1501, GN0101]    20161120
# 188101          [GN1501, GN1504, GN0303, GN0301]    20161223
#
#                          album_name  album_id  artist_id_basket  \
# id
# 686323      LOST IN THE CITY Part.1   2648829          [913839]
# 425790         소박한 과욕 (Small Greed)   2655691          [827147]
# 505516                         FLIP   2698723          [786648]
# 598924                         FLIP   2698723          [786648]
# 73959         EVERYTHING YOU WANTED  10008163          [443420]
# 19670                    Night Vibe  10057734          [340668]
# 588686                     BLEACHED  10064496          [688432]
# 140795                     BLEACHED  10064496          [688432]
# 644650                     BLEACHED  10064496          [688432]
# 447716                     BLEACHED  10064496          [688432]
# 927     H.A.L.F (Have.A.Little.Fun)  10068509          [786648]
# 357102  H.A.L.F (Have.A.Little.Fun)  10068509          [786648]
# 24303          Smile (Prod. WOOGIE)  10101862          [762567]
# 160629                          Tru  10102291         [1865552]
# 460646         슬기로운 감빵생활 OST Part.6  10121659         [1866689]
# 556615               ROLLING STONES  10148746          [785579]
# 414424        REWIND MY TAPE part.1  10150879          [785579]
# 46084             건반 위의 하이에나 Part.4  10160487  [688432, 756531]
# 5542                           SOJU  10170458          [443420]
# 176997                      PLAY ME  10173722          [785579]
# 338227        EVERYTHING YOU WANTED  10008163          [443420]
# 130196              안투라지 MIXTAPE #5  10016733          [568051]
# 188101                 안투라지 MIXTAPE  10025588          [568051]
#
#                                song_name song_gn_gnr_basket  \
# id
# 686323                      ROLL & SMOKE   [GN0500, GN0300]
# 425790                 교만 (Prod. Woogie)   [GN0500, GN0300]
# 505516                      차차 (Cha Cha)           [GN0300]
# 598924                    I Call It Love           [GN0300]
# 73959        Alone Tonight (Feat. Sik-K)           [GN0400]
# 19670           아침에 다시 얘기해 (Feat. Sik-K)           [GN0300]
# 588686              So Bad (Feat. Sik-K)           [GN0300]
# 140795                             입버릇처럼           [GN0300]
# 644650                남아있어 (Feat. Crush)           [GN0300]
# 447716         너도 (Feat. Cha Cha Malone)           [GN0300]
# 927                  Interlude: 24 7 365           [GN0300]
# 357102              이해해줘 (Somebody Else)           [GN0300]
# 24303               Smile (Prod. WOOGIE)           [GN1300]
# 160629                 Tru (Feat. Sik-K)   [GN0400, GN2500]
# 460646              향수 (Prod. by WOOGIE)   [GN1500, GN0300]
# 556615       ROLLING STONES (Feat. 카더가든)           [GN0400]
# 414424     HAVE A GOOD NIGHT (Feat. ELO)           [GN0400]
# 46084                                주지마           [GN0100]
# 5542               SOJU (Feat. 2 Chainz)           [GN0300]
# 176997     PLAY ME (Feat. 식케이, PENOMECO)           [GN0400]
# 338227                           곁에 있어주길           [GN0400]
# 130196  너라도 (Feat. 김보아 of SPICA) (Inst.)   [GN1500, GN0100]
# 188101          너라도 (Feat. 김보아 Of SPICA)   [GN1500, GN0300]
#
#          artist_name_basket
# id
# 686323        [BRYAN CHASE]
# 425790  [FUTURISTIC SWAVER]
# 505516        [식케이 (Sik-K)]
# 598924        [식케이 (Sik-K)]
# 73959                 [박재범]
# 19670                 [보이비]
# 588686                 [로꼬]
# 140795                 [로꼬]
# 644650                 [로꼬]
# 447716                 [로꼬]
# 927           [식케이 (Sik-K)]
# 357102        [식케이 (Sik-K)]
# 24303            [Phe REDS]
# 160629                [정진형]
# 460646                [우원재]
# 556615             [WOOGIE]
# 414424             [WOOGIE]
# 46084     [로꼬, 화사 (Hwa Sa)]
# 5542                  [박재범]
# 176997             [WOOGIE]
# 338227                [박재범]
# 130196         [레디 (Reddy)]
# 188101         [레디 (Reddy)]

# %%
song_meta_indexed.loc[reco_result].head(10)
# Out:
#                   song_gn_dtl_gnr_basket  issue_date  \
# id
# 161768                  [GN0303, GN0301]    20170605
# 423915                  [GN0303, GN0301]    20161029
# 413422          [GN0401, GN0403, GN0402]    20161020
# 384786                  [GN0303, GN0301]    20171008
# 313223                  [GN0303, GN0301]    20170921
# 525203                  [GN0303, GN0301]    20170916
# 645130                  [GN0303, GN0301]    20160720
# 18117   [GN0501, GN0304, GN0505, GN0301]    20170315
# 505036          [GN0401, GN0403, GN0402]    20160324
# 256899                  [GN0303, GN0301]    20171207
#
#                          album_name  album_id          artist_id_basket  \
# id
# 161768  H.A.L.F (Have.A.Little.Fun)  10068509                  [786648]
# 423915                    RING RING  10010740                  [786648]
# 413422        EVERYTHING YOU WANTED  10008163                  [443420]
# 384786                      Jasmine  10100658                  [943516]
# 313223                      BOYCOLD  10097911                  [786648]
# 525203          Dingo X H1GHR MUSIC  10096204  [786648, 943511, 443420]
# 645130                         FLIP   2698723                  [786648]
# 18117            Coming To You Live  10046002                  [943516]
# 505036              130 mood : TRBL   2674623                  [880630]
# 256899                          Her  10118005                  [943516]
#
#                                      song_name song_gn_gnr_basket  \
# id
# 161768           party (SHUT DOWN) (Feat. 크러쉬)           [GN0300]
# 423915                    RING RING (Feat. 개코)           [GN0300]
# 413422  All I Wanna Do (K) (Feat. Hoody, Loco)           [GN0400]
# 384786                                 Jasmine           [GN0300]
# 313223          이어폰 (Earphone) (Prod. BOYCOLD)           [GN0300]
# 525203                 iffy (Prod. GroovyRoom)           [GN0300]
# 645130                        랑데뷰 (Rendezvous)           [GN0300]
# 18117                     Laputa (Feat. Crush)   [GN0500, GN0300]
# 505036                D (half moon) (Feat. 개코)           [GN0400]
# 256899                            Martini Blue           [GN0300]
#
#               artist_name_basket
# id
# 161768             [식케이 (Sik-K)]
# 423915             [식케이 (Sik-K)]
# 413422                     [박재범]
# 384786                [DPR LIVE]
# 313223             [식케이 (Sik-K)]
# 525203  [식케이 (Sik-K), pH-1, 박재범]
# 645130             [식케이 (Sik-K)]
# 18117                 [DPR LIVE]
# 505036                    [DEAN]
# 256899                [DPR LIVE]

# %%
def get_reco_song_w2v(song_list, ignore_list=[], size=100):
    reco_num_per_song = int(size / len(song_list)) + 1
    reco_num_per_song = max(reco_num_per_song, 10) 
    reco_list = []
    
    for idx, song in enumerate(song_list):
        if str(song) in model.wv.vocab:
            reco_list.extend(model.wv.most_similar(str(song), topn=reco_num_per_song))
    #print(reco_list)
        
    reco_df = pd.DataFrame(reco_list, columns=['song', 'dist'])
    reco_count_df = reco_df.groupby('song')['dist'].sum().sort_values(ascending=False).reset_index()
    reco_count_df['song_id'] = reco_count_df['song'].apply(lambda x : int(x))
    reco_top = reco_count_df[~reco_count_df['song_id'].isin(song_list+ignore_list)].head(size)

    #print(reco_top[['song_id', 'dist']])
    return reco_top[['song_id', 'dist']]

# %%
def reco_song_w2v(song_list, ignore_list=[], size=100):
    if len(song_list) == 0:
        return []
    reco_top = get_reco_song_w2v(song_list, ignore_list, size)
    if len(reco_top) == 0:
        return []
    return reco_top['song_id'].tolist()

# %%
song_index = 21242

# %%
reco_result = reco_song_w2v(val.iloc[song_index]['songs'])

# %%
len(set(reco_result))
# Out:
# 100

# %%
len(set(reco_result) & set(val.iloc[song_index]['songs']))
# Out:
# 0

# %%
song_meta_indexed.loc[val.iloc[song_index]['songs']]
# Out:
#                           song_gn_dtl_gnr_basket  issue_date  \
# id
# 686323  [GN0509, GN0501, GN0304, GN0505, GN0301]    20151105
# 425790          [GN0501, GN0304, GN0505, GN0301]    20151210
# 505516                          [GN0303, GN0301]    20160720
# 598924                          [GN0303, GN0301]    20160720
# 73959                   [GN0401, GN0403, GN0402]    20161020
# 19670                           [GN0303, GN0301]    20170425
# 588686                          [GN0303, GN0301]    20170525
# 140795                          [GN0303, GN0301]    20170525
# 644650                          [GN0303, GN0301]    20170525
# 447716                          [GN0303, GN0301]    20170525
# 927                                     [GN0301]    20170605
# 357102                          [GN0303, GN0301]    20170605
# 24303                           [GN1301, GN1302]    20171013
# 160629                  [GN0401, GN0403, GN0402]    20171015
# 460646          [GN1501, GN1504, GN0303, GN0301]    20171220
# 556615                          [GN0401, GN0403]    20180318
# 414424                          [GN0401, GN0403]    20180323
# 46084                                   [GN0101]    20180421
# 5542                            [GN0302, GN0301]    20180525
# 176997                          [GN0401, GN0403]    20180606
# 338227                  [GN0401, GN0403, GN0402]    20161020
# 130196                          [GN1501, GN0101]    20161120
# 188101          [GN1501, GN1504, GN0303, GN0301]    20161223
#
#                          album_name  album_id  artist_id_basket  \
# id
# 686323      LOST IN THE CITY Part.1   2648829          [913839]
# 425790         소박한 과욕 (Small Greed)   2655691          [827147]
# 505516                         FLIP   2698723          [786648]
# 598924                         FLIP   2698723          [786648]
# 73959         EVERYTHING YOU WANTED  10008163          [443420]
# 19670                    Night Vibe  10057734          [340668]
# 588686                     BLEACHED  10064496          [688432]
# 140795                     BLEACHED  10064496          [688432]
# 644650                     BLEACHED  10064496          [688432]
# 447716                     BLEACHED  10064496          [688432]
# 927     H.A.L.F (Have.A.Little.Fun)  10068509          [786648]
# 357102  H.A.L.F (Have.A.Little.Fun)  10068509          [786648]
# 24303          Smile (Prod. WOOGIE)  10101862          [762567]
# 160629                          Tru  10102291         [1865552]
# 460646         슬기로운 감빵생활 OST Part.6  10121659         [1866689]
# 556615               ROLLING STONES  10148746          [785579]
# 414424        REWIND MY TAPE part.1  10150879          [785579]
# 46084             건반 위의 하이에나 Part.4  10160487  [688432, 756531]
# 5542                           SOJU  10170458          [443420]
# 176997                      PLAY ME  10173722          [785579]
# 338227        EVERYTHING YOU WANTED  10008163          [443420]
# 130196              안투라지 MIXTAPE #5  10016733          [568051]
# 188101                 안투라지 MIXTAPE  10025588          [568051]
#
#                                song_name song_gn_gnr_basket  \
# id
# 686323                      ROLL & SMOKE   [GN0500, GN0300]
# 425790                 교만 (Prod. Woogie)   [GN0500, GN0300]
# 505516                      차차 (Cha Cha)           [GN0300]
# 598924                    I Call It Love           [GN0300]
# 73959        Alone Tonight (Feat. Sik-K)           [GN0400]
# 19670           아침에 다시 얘기해 (Feat. Sik-K)           [GN0300]
# 588686              So Bad (Feat. Sik-K)           [GN0300]
# 140795                             입버릇처럼           [GN0300]
# 644650                남아있어 (Feat. Crush)           [GN0300]
# 447716         너도 (Feat. Cha Cha Malone)           [GN0300]
# 927                  Interlude: 24 7 365           [GN0300]
# 357102              이해해줘 (Somebody Else)           [GN0300]
# 24303               Smile (Prod. WOOGIE)           [GN1300]
# 160629                 Tru (Feat. Sik-K)   [GN0400, GN2500]
# 460646              향수 (Prod. by WOOGIE)   [GN1500, GN0300]
# 556615       ROLLING STONES (Feat. 카더가든)           [GN0400]
# 414424     HAVE A GOOD NIGHT (Feat. ELO)           [GN0400]
# 46084                                주지마           [GN0100]
# 5542               SOJU (Feat. 2 Chainz)           [GN0300]
# 176997     PLAY ME (Feat. 식케이, PENOMECO)           [GN0400]
# 338227                           곁에 있어주길           [GN0400]
# 130196  너라도 (Feat. 김보아 of SPICA) (Inst.)   [GN1500, GN0100]
# 188101          너라도 (Feat. 김보아 Of SPICA)   [GN1500, GN0300]
#
#          artist_name_basket
# id
# 686323        [BRYAN CHASE]
# 425790  [FUTURISTIC SWAVER]
# 505516        [식케이 (Sik-K)]
# 598924        [식케이 (Sik-K)]
# 73959                 [박재범]
# 19670                 [보이비]
# 588686                 [로꼬]
# 140795                 [로꼬]
# 644650                 [로꼬]
# 447716                 [로꼬]
# 927           [식케이 (Sik-K)]
# 357102        [식케이 (Sik-K)]
# 24303            [Phe REDS]
# 160629                [정진형]
# 460646                [우원재]
# 556615             [WOOGIE]
# 414424             [WOOGIE]
# 46084     [로꼬, 화사 (Hwa Sa)]
# 5542                  [박재범]
# 176997             [WOOGIE]
# 338227                [박재범]
# 130196         [레디 (Reddy)]
# 188101         [레디 (Reddy)]

# %%
song_meta_indexed.loc[reco_result].head(10)
# Out:
#                           song_gn_dtl_gnr_basket  issue_date  \
# id
# 154874                  [GN0401, GN0403, GN0402]    20161020
# 139811                          [GN0401, GN0403]    20150119
# 365689  [GN0501, GN0304, GN0301, GN0505, GN0303]    20160307
# 273615          [GN0501, GN0304, GN0505, GN0301]    20170315
# 678553                          [GN0303, GN0301]    20170718
# 674243                          [GN0303, GN0301]    20170228
# 459436                          [GN0303, GN0301]    20161115
# 450996                          [GN0303, GN0301]    20170515
# 204867                          [GN0105, GN0101]    20180512
# 390837                                  [GN0301]    20140918
#
#                       album_name  album_id artist_id_basket  \
# id
# 154874     EVERYTHING YOU WANTED  10008163         [443420]
# 139811                    Krream   2300299         [785673]
# 365689                    Ma Fam   2671238         [787227]
# 273615        Coming To You Live  10046002         [943516]
# 678553                 Fireworks  10080647         [525805]
# 674243          MUGGLES` MANSION  10042292         [724086]
# 459436                       빨래방  10015228         [715089]
# 450996                        칼춤  10061940         [716984]
# 204867  더 콜 (The Call) 첫 번째 프로젝트  10166117   [6502, 739740]
# 390837                 Champagne   2282438         [785568]
#
#                                           song_name song_gn_gnr_basket  \
# id
# 154874                    전화기를 꺼놔 Remix (Feat. ELO)           [GN0400]
# 139811                         Hug Me Just One Time           [GN0400]
# 365689                                       Ma Fam   [GN0500, GN0300]
# 273615                                Cheese & Wine   [GN0500, GN0300]
# 678553                                          Woo           [GN0300]
# 674243  Don`t shoot me MAMA (Feat. Car, the garden)           [GN0300]
# 459436                         빨래방 (Feat. BK, 입술세개)           [GN0300]
# 450996                     아무렇지 않게 (Feat. 루이 of 긱스)           [GN0300]
# 204867                                    I will be           [GN0100]
# 390837             Champagne (Feat. S`WAY.D , MIZI)           [GN0300]
#
#            artist_name_basket
# id
# 154874                  [박재범]
# 139811                [크리시베어]
# 365689      [페노메코 (PENOMECO)]
# 273615             [DPR LIVE]
# 678553           [긱스 (Geeks)]
# 674243  [코드 쿤스트 (CODE KUNST)]
# 459436                  [송승민]
# 450996                  [한요한]
# 204867     [김범수, BewhY (비와이)]
# 390837           [Wet Packer]

# %%
def get_reco_song_tag_co_occur(tag_list, ignore_list=[], size=100):
    tag_song_df = co_tag_song_count_df[co_tag_song_count_df['tag'].isin(tag_list)]
    #print(tag_song_df)
    if tag_song_df.shape[0] == 0:
        return []
    tag_song_count_df = tag_song_df.groupby('song')['count_scale'].sum().reset_index()
    #print(tag_song_count_df)
    tag_song_count_df_remove_ignore = tag_song_count_df[~tag_song_count_df['song'].isin(ignore_list)]
   
    tag_song_count_top = tag_song_count_df_remove_ignore.sort_values('count_scale', ascending=False).head(size)
    #print(tag_song_count_top.head(20))
    return tag_song_count_top

# %%
def reco_song_tag_co_occur(tag_list, ignore_list=[], size=100):
    tags = list(set(tag_list))
    if len(tags) == 0:
        return []
    reco_top = get_reco_song_tag_co_occur(tags, ignore_list, size)
    if len(reco_top) == 0:
        return []
    return reco_top['song'].tolist()

# %%
song_index = 100

# %%
reco_result = reco_song_tag_co_occur(val.iloc[song_index]['tags'])

# %%
len(set(reco_result))
# Out:
# 100

# %%
val.iloc[song_index]['tags']
# Out:
# ['JPOP']

# %%
song_meta_indexed.loc[reco_result]
# Out:
#                   song_gn_dtl_gnr_basket  issue_date               album_name  \
# id
# 204900          [GN1912, GN1903, GN1901]    20110922        Rockin` The World
# 580527          [GN1912, GN1903, GN1901]    20100407                    Earth
# 632189          [GN1912, GN1902, GN1901]    20050921              Planetarium
# 624957          [GN1912, GN1902, GN1901]    20070321                Time Note
# 608666          [GN1912, GN1902, GN1901]    20060614            Good-Bye Days
# ...                                  ...         ...                      ...
# 62597           [GN1912, GN1902, GN1901]    20070404        Can`t Buy My Love
# 206932                  [GN1912, GN1901]    20170213                     Milk
# 572471          [GN1912, GN1902, GN1901]    20040818  Kingyohanabi (금붕어 불꽃놀이)
# 225645  [GN1910, GN1906, GN1912, GN1901]    20070620                All Yours
# 697026  [GN1910, GN1906, GN1901, GN1911]    19990428               First Love
#
#         album_id artist_id_basket  \
# id
# 204900   2014833         [556760]
# 580527   2115327         [664751]
# 632189    308876         [161289]
# 624957    359452         [230202]
# 608666    332759         [182103]
# ...          ...              ...
# 62597     349846         [182103]
# 206932  10061179        [1703924]
# 572471     40363         [161289]
# 225645    352958         [160045]
# 697026     72391          [11179]
#
#                                                 song_name song_gn_gnr_basket  \
# id
# 204900  Some Like It Hot!! Samurai Heart (애니메이션 `은혼` 엔...           [GN1900]
# 580527                        Maboroshino Inochi (환상의 생명)           [GN1900]
# 632189                     Planetarium (TBS `꽃보다 남자` 삽입곡)           [GN1900]
# 624957       Kawaranai Mono (변하지 않는 것) (`시간을 달리는 소녀` 삽입곡)           [GN1900]
# 608666                                      Good-Bye Days           [GN1900]
# ...                                                   ...                ...
# 62597                                            Che.R.Ry           [GN1900]
# 206932                                         Hikarunara           [GN1900]
# 572471                            Kingyohanabi (금붕어 불꽃놀이)           [GN1900]
# 225645  Konnani Chikakude (이렇게 가까이에서) (애니메이션 `노다메칸타빌레`...           [GN1900]
# 697026                                         First Love           [GN1900]
#
#               artist_name_basket
# id
# 204900                  [SPYAIR]
# 580527          [SEKAI NO OWARI]
# 632189               [Otsuka Ai]
# 624957              [Oku Hanako]
# 608666                     [Yui]
# ...                          ...
# 62597                      [Yui]
# 206932             [Goose house]
# 572471               [Otsuka Ai]
# 225645             [Crystal Kay]
# 697026  [Hikaru Utada (우타다 히카루)]
#
# [100 rows x 8 columns]

# %%
def reco_song_co_occur_album_artist_count(song_list):
    #print(song_list)
    reco_ss = get_reco_song_co_occur(song_list, [], 200)
    
    if len(reco_ss) == 0:
        return []
    
    reco_ss.columns = ['song', 'count_song']
    reco_ss = pd.merge(reco_ss, song_album_df, how='left', left_on='song', right_on='song')
    #print(reco_ss)
    
    song_album_count = song_album_df.loc[song_list].groupby('album').size().reset_index()
    song_album_count.columns = ['album', 'count']
    #print(song_album_count)
    song_album_count = song_album_count.set_index('album')
       
    def get_album_count(album):
        count = 1
        if album in song_album_count.index:
            #print(song_album_count.loc[album]['count'])
            count = count + song_album_count.loc[album]['count']
        return math.log(count+1)
    reco_ss['count_album'] = reco_ss['album'].apply(get_album_count)
   

    reco_ss = pd.merge(reco_ss, song_meta[['id', 'artist_name_basket']], how='left', left_on='song', right_on='id')
    #print(reco_ss)
    
    song_artist_count = song_artist_df.loc[song_list].groupby('artist').size().reset_index()
    song_artist_count.columns = ['artist', 'count']
    #print(song_artist_count)
    song_artist_count = song_artist_count.set_index('artist')
       
    def get_artist_count(artist_list):    
        count = 1
        if len(artist_list) == 0:
            return count
        for artist in artist_list:
            if artist in song_artist_count.index:
                #print(song_artist_count.loc[artist]['count'])
                count = count + song_artist_count.loc[artist]['count']
        return math.log(max(int(count / len(artist_list)), 1)+1)
    reco_ss['count_artist'] = reco_ss['artist_name_basket'].apply(get_artist_count)
    
    
    reco_ss = pd.merge(reco_ss, song_meta[['id', 'song_gn_dtl_gnr_basket']], how='left', left_on='id', right_on='id')
    #print(reco_ss)
    song_gn_count = song_gn_df.loc[song_list].groupby('gn').size().reset_index()
    song_gn_count.columns = ['gn', 'count']
    #print(song_artist_count)
    song_gn_count = song_gn_count.set_index('gn')
    
    def get_gn_count(gn_list):
        count = 1
        if len(gn_list) == 0:
            return count
        for gn in gn_list:
            if gn in song_gn_count.index:
                #print(song_gn_count.loc[gn]['count'])
                count = count + song_gn_count.loc[gn]['count']
        return math.log(max(int(count / len(gn_list)), 1))
    reco_ss['count_gn'] = reco_ss['song_gn_dtl_gnr_basket'].apply(get_gn_count)

    reco = reco_ss
    reco['count'] = reco.apply(lambda x : x.count_song + x.count_album * 5 + x.count_artist * 5 + x.count_gn, axis=1)
    reco = reco.sort_values('count', ascending=False)  
    #print(reco.head(10))
    return reco.head(100)['song'].tolist()

# %%
song_index = 30

# %%
song_meta_indexed.loc[val.iloc[song_index]['songs']]
# Out:
#                   song_gn_dtl_gnr_basket  issue_date              album_name  \
# id
# 559102                  [GN0303, GN0301]    20140716            Up All Night
# 415189                  [GN0303, GN0301]    20150213                    Life
# 474374                  [GN0303, GN0301]    20120314                   그냥 가요
# 130275                  [GN0303, GN0301]    20120703               2 4 : 2 6
# 156278                  [GN0303, GN0301]    20120703               2 4 : 2 6
# 45581                   [GN0303, GN0301]    20110309  Officially Missing You
# 47612                   [GN0303, GN0301]    20150807                  My Man
# 583792                  [GN0303, GN0301]    20130429                Backpack
# 403438          [GN0401, GN0403, GN0402]    20130930               Jackasoul
# 70143                   [GN0303, GN0301]    20140314     그린라이트 (GREEN LIGHT)
# 529758  [GN0501, GN0304, GN0505, GN0301]    20090728         Daily Apartment
# 320185                  [GN0303, GN0301]    20101012                   Smoke
# 275414                  [GN0303, GN0301]    20110309  Officially Missing You
#
#         album_id artist_id_basket                             song_name  \
# id
# 559102   2267501         [532029]  Up All Night (Feat. Mayson The Soul)
# 415189   2304412         [837535]                    Life (Feat. 매드클라운)
# 474374   2093067         [525805]            그냥 가요 (Feat. 조현아 Of 어반자카파)
# 130275   2134788         [532029]        Nike Shoes (Feat. Dynamic Duo)
# 156278   2134788         [532029]                     If I Die Tomorrow
# 45581    1196552         [525805]                                   답답해
# 47612    2333671         [786648]                                My Man
# 583792   2183300         [525805]                      비가오네 (Feat. 박수민)
# 403438   2203237         [735506]                 홀리데이 (Feat. Beenzino)
# 70143    2241137         [761256]                   그린라이트 (GREEN LIGHT)
# 529758    618751         [425072]                             Neon City
# 320185   1037885         [501323]                Smoke (Feat. Beenzino)
# 275414   1196552         [525805]                Officially Missing You
#
#        song_gn_gnr_basket      artist_name_basket
# id
# 559102           [GN0300]        [빈지노 (Beenzino)]
# 415189           [GN0300]    [러버소울 (Rubber Soul)]
# 474374           [GN0300]            [긱스 (Geeks)]
# 130275           [GN0300]        [빈지노 (Beenzino)]
# 156278           [GN0300]        [빈지노 (Beenzino)]
# 45581            [GN0300]            [긱스 (Geeks)]
# 47612            [GN0300]           [식케이 (Sik-K)]
# 583792           [GN0300]            [긱스 (Geeks)]
# 403438           [GN0400]                  [카더가든]
# 70143            [GN0300]  [트로이 (범키, 칸토, 재웅, 창우)]
# 529758   [GN0500, GN0300]              [P` Skool]
# 320185           [GN0300]              [VidaLoca]
# 275414           [GN0300]            [긱스 (Geeks)]

# %%
reco_result = reco_song_co_occur_album_artist_count(val.iloc[song_index]['songs'])

# %%
song_meta_indexed.loc[reco_result].head(10)
# Out:
#                   song_gn_dtl_gnr_basket  issue_date  \
# id
# 347303                  [GN0303, GN0301]    20120703
# 635759                  [GN0303, GN0301]    20120703
# 221986  [GN0501, GN0304, GN0505, GN0301]    20131218
# 587912                  [GN0303, GN0301]    20120703
# 391992                  [GN0303, GN0301]    20140716
# 232305                  [GN0303, GN0301]    20121031
# 237407                  [GN0303, GN0301]    20140319
# 400157                  [GN0303, GN0301]    20121031
# 109190                  [GN0303, GN0301]    20101026
# 534517                  [GN0303, GN0301]    20130429
#
#                            album_name  album_id artist_id_basket  \
# id
# 347303                      2 4 : 2 6   2134788         [532029]
# 635759                      2 4 : 2 6   2134788         [532029]
# 221986             Dali, Van, Picasso   2222076         [532029]
# 587912                      2 4 : 2 6   2134788         [532029]
# 391992                   Up All Night   2267501         [532029]
# 232305  Primary And The Messengers LP   2161126          [35682]
# 237407                             감아   2242936         [688432]
# 400157  Primary And The Messengers LP   2161126          [35682]
# 109190                     Lifes Like   1053151         [504524]
# 534517                       Backpack   2183300         [525805]
#
#                                  song_name song_gn_gnr_basket  \
# id
# 347303                      Boogie On & On           [GN0300]
# 635759                            Aqua Man           [GN0300]
# 221986                  Dali, Van, Picasso   [GN0500, GN0300]
# 587912          (Bonus Track) Always Awake           [GN0300]
# 391992                     How Do I Look ?           [GN0300]
# 232305                 멀어 (Feat. Beenzino)           [GN0300]
# 237407                    감아 (Feat. Crush)           [GN0300]
# 400157  3호선 매봉역 (Feat. Paloalto, Beenzino)           [GN0300]
# 109190                                 아까워           [GN0300]
# 534517               Wash Away (Feat. 에일리)           [GN0300]
#
#        artist_name_basket
# id
# 347303   [빈지노 (Beenzino)]
# 635759   [빈지노 (Beenzino)]
# 221986   [빈지노 (Beenzino)]
# 587912   [빈지노 (Beenzino)]
# 391992   [빈지노 (Beenzino)]
# 232305            [프라이머리]
# 237407               [로꼬]
# 400157            [프라이머리]
# 109190        [Jazzyfact]
# 534517       [긱스 (Geeks)]

# %%
pp_song_count_df_top200 = pp_song_count_df.head(200)

# %%
reco_song_count = 0

def song_reco_final(song_list, tag_list):
    global reco_song_count
    song_len = len(song_list)
    tag_len = len(tag_list)

    reco = []
    extra = 100
    
    if reco_song_count % 1000 == 0:
        print(f'===== working at {reco_song_count},  {datetime.now()} =====')
    
    if song_len > 0 and tag_len > 0:
        reco = reco_song_co_occur_album_artist_count(song_list)
        extra = 100 - len(reco)
        if extra > 0:
            reco.extend(reco_song_w2v(song_list, reco, extra))
        extra = 100 - len(reco)
        if extra > 0:
            reco.extend(reco_song_tag_co_occur(tag_list, song_list+reco, extra))
    elif song_len > 0 and tag_len == 0:
        reco = reco_song_co_occur_album_artist_count(song_list)
        extra = 100 - len(reco)
        if extra > 0:
            reco.extend(reco_song_w2v(song_list, reco, extra))
    elif song_len == 0 and tag_len > 0:
        reco = reco_song_tag_co_occur(tag_list)
    
    extra = 100 - len(reco)
    if extra > 0:
        reco.extend(pp_song_count_df_top200[~pp_song_count_df_top200.index.isin(song_list+reco)].head(extra).index.tolist())
    reco_song_count = reco_song_count + 1
    return reco[:100]

# %%
val['song_reco'] = val.apply(lambda x : song_reco_final(x.songs, x.tags), axis=1)
# Out:
# ===== working at 0,  2020-07-22 04:27:21.497503 =====
# ===== working at 1000,  2020-07-22 04:36:30.354186 =====
# ===== working at 2000,  2020-07-22 04:45:46.409760 =====
# ===== working at 3000,  2020-07-22 04:54:33.774713 =====
# ===== working at 4000,  2020-07-22 05:03:39.934411 =====
# ===== working at 5000,  2020-07-22 05:12:57.130914 =====
# ===== working at 6000,  2020-07-22 05:22:11.983371 =====
# ===== working at 7000,  2020-07-22 05:31:30.130962 =====
# ===== working at 8000,  2020-07-22 05:40:51.242393 =====
# ===== working at 9000,  2020-07-22 05:49:59.691199 =====
# ===== working at 10000,  2020-07-22 05:59:14.171713 =====
# ===== working at 11000,  2020-07-22 06:08:37.556433 =====
# ===== working at 12000,  2020-07-22 06:17:58.252099 =====
# ===== working at 13000,  2020-07-22 06:27:19.576141 =====
# ===== working at 14000,  2020-07-22 06:36:39.940941 =====
# ===== working at 15000,  2020-07-22 06:45:49.050147 =====
# ===== working at 16000,  2020-07-22 06:55:09.680304 =====
# ===== working at 17000,  2020-07-22 07:04:26.160275 =====
# ===== working at 18000,  2020-07-22 07:13:48.268127 =====
# ===== working at 19000,  2020-07-22 07:23:03.957369 =====
# ===== working at 20000,  2020-07-22 07:32:18.463949 =====
# ===== working at 21000,  2020-07-22 07:41:29.261313 =====
# ===== working at 22000,  2020-07-22 07:50:31.570271 =====
# ===== working at 23000,  2020-07-22 07:59:42.724462 =====

# %%
val['song_reco_len'] = val['song_reco'].apply(lambda x : len(set(x)))

# %%
val.describe()
# Out:
#                   id      like_cnt     songs_len      tags_len  song_reco_len
# count   23015.000000  23015.000000  23015.000000  23015.000000        23015.0
# mean    76737.031371     89.096937     18.301065      1.187834          100.0
# std     44234.398231    511.797842     21.544313      1.575660            0.0
# min         3.000000      0.000000      0.000000      0.000000          100.0
# 25%     38458.000000      2.000000      6.000000      0.000000          100.0
# 50%     76896.000000      7.000000     11.000000      1.000000          100.0
# 75%    115060.000000     24.000000     23.000000      2.000000          100.0
# max    153424.000000  32695.000000    100.000000      5.000000          100.0

# %%
val[['id', 'song_reco']].to_csv('song_reco_result.csv')

# %%
song_reco = pd.read_csv('song_reco_result.csv')

# %%
song_reco['song_reco'] = song_reco['song_reco'].apply(lambda x : eval(x))

# %%
val['song_reco'] = song_reco['song_reco']

# %%
tag_reco = pd.read_csv('tag_reco_result.csv')

# %%
tag_reco['tag_reco'] = tag_reco['tag_reco'].apply(lambda x : eval(x))

# %%
val['tag_reco'] = tag_reco['tag_reco']

# %%
answers = []

def make_answer(pid, songs, tags):
    answers.append({
        "id": pid,
        "songs": songs,
        "tags": tags
    })

# %%
result = val.apply(lambda x : make_answer(x.id, x.song_reco, x.tag_reco), axis=1)

# %%
import io
import os
import json
import distutils.dir_util

def write_json(data, fname):
    def _conv(o):
        if isinstance(o, (np.int64, np.int32)):
            return int(o)
        raise TypeError

    parent = os.path.dirname(fname)
    distutils.dir_util.mkpath("./arena_data/" + parent)
    with io.open("./arena_data/" + fname, "w", encoding="utf-8") as f:
        json_str = json.dumps(data, ensure_ascii=False, default=_conv)
        f.write(json_str)

# %%
write_json(answers, 'results.json')
